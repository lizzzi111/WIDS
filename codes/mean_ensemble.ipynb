# %%
import pandas as pd

# %%
# GOOGLE COLAB SETUP

# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
os.chdir('drive/My Drive/Colab Notebooks/WIDS/WIDS/')

# %%
os.listdir("./submissions")
# Out:
# ['lgb_v1_90545.csv',
#  'lgb_v2_90538.csv',
#  'lgb_v3_90547.csv',
#  'lgb_v4_90630.csv',
#  'lgb_v5_90389.csv',
#  'lgb_v6_90427.csv',
#  'lgb_v7_90271.csv',
#  'lgb_v8_90614.csv',
#  'lgb_v9_90627.csv',
#  'lgb_v10_90627.csv',
#  'lgb_v11_90707.csv',
#  'lgb_v12_90622.csv',
#  'ensemble_1.csv',
#  'lgb_v14_90605.csv',
#  'lgb_v15_90624.csv',
#  'ensemble_2.csv',
#  'ensemble_3.csv',
#  'stack_lgb14_88530.csv',
#  'lgb_v17_90519.csv',
#  'stack_lgb16_89283.csv',
#  'stack_ridge17_90790.csv',
#  'ensemble_v17_v6_v14.csv',
#  'ensemble_3times_17_v6_v14.csv',
#  'lgb_v18_90494.csv',
#  'lgb_v19_0.csv',
#  'lgb_v20_90522.csv',
#  'lgb_v21_90522.csv',
#  'stack_ridge_v222_94153.csv',
#  'ensemble_4times_17_v6_v14_v20_stackridge222.csv',
#  'ensemble_4times_17_v6_v14_v20.csv',
#  'lgb_v21_90535.csv',
#  'lgb_v26_90633.csv',
#  'lgb_v28_90684.csv',
#  'lgb_v29_90658.csv']

# %%
submission1 = pd.read_csv("./submissions/lgb_v17_90519.csv")
submission2 = pd.read_csv("./submissions/lgb_v6_90427.csv")
submission3 = pd.read_csv("./submissions/lgb_v14_90605.csv")
submission4 = pd.read_csv("./submissions/lgb_v20_90522.csv")

# %%
submission1['hospital_death'] = (4*submission1['hospital_death']+submission2['hospital_death']+submission3['hospital_death']+submission4['hospital_death'])/7

# %%
submission1.to_csv("./submissions/ensemble_4times_17_v6_v14_v20.csv", index=False)

# %%
submission1 = pd.read_csv("./submissions/lgb_v21_90535.csv")
submission2 = pd.read_csv("./submissions/lgb_v26_90633.csv")
submission3 = pd.read_csv("./submissions/lgb_v28_90684.csv")
submission4 = pd.read_csv("./submissions/lgb_v29_90658.csv")
submission5 = pd.read_csv("./submissions/lgb_v17_90519.csv")

# %%
submission1['hospital_death'] = (submission1['hospital_death']+submission2['hospital_death']+submission3['hospital_death']+submission4['hospital_death']+submission5['hospital_death'])/5

# %%
submission1.to_csv("./submissions/ensemble_v17_v21_v26_v28_v29.csv", index=False)
