# %%
pd.options.display.max_rows    = 999
pd.options.display.max_columns = 999

# %%
###############################
#                             #
#        ENCODE FACTORS       #
#                             #
###############################

# performs label encoding
def reduce_mem_usage(df, verbose = True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2    
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)    
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose: 
        print('Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)'.format(end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df

from sklearn.preprocessing import LabelEncoder, OneHotEncoder
def label_encoding(df_train, df_valid, df_test):
    
    factors = df_train.select_dtypes('object').columns
    
    lbl = LabelEncoder()

    for f in factors:        
        lbl.fit(list(df_train[f].values)+ list(df_test[f].values) + list(df_valid[f].values) )
        df_train[f] = lbl.transform(list(df_train[f].values))
        df_valid[f] = lbl.transform(list(df_valid[f].values))
        df_test[f]  = lbl.transform(list(df_test[f].values))

    return df_train, df_valid, df_test

from sklearn import base
class KFoldTargetEncoderTrain(base.BaseEstimator,
                               base.TransformerMixin):
    def __init__(self,colnames,targetName,
                  n_fold=5, verbosity=True,
                  discardOriginal_col=False):
        self.colnames = colnames
        self.targetName = targetName
        self.n_fold = n_fold
        self.verbosity = verbosity
        self.discardOriginal_col = discardOriginal_col
    def fit(self, X, y=None):
        return self
    def transform(self,X):
        assert(type(self.targetName) == str)
        assert(type(self.colnames) == str)
        assert(self.colnames in X.columns)
        assert(self.targetName in X.columns)
        mean_of_target = X[self.targetName].mean()
        kf = KFold(n_splits = self.n_fold,
                   shuffle = False, random_state=2019)
        col_mean_name = self.colnames + '_' + 'Kfold_Target_Enc'
        X[col_mean_name] = np.nan
        for tr_ind, val_ind in kf.split(X):
            X_tr, X_val = X.iloc[tr_ind], X.iloc[val_ind]
            X.loc[X.index[val_ind], col_mean_name] =  X_val[self.colnames].map(X_tr.groupby(self.colnames)[self.targetName].mean())
            X[col_mean_name].fillna(mean_of_target, inplace = True)
        if self.verbosity:
            encoded_feature = X[col_mean_name].values
            print('Correlation between the new feature, {} and, {} is {}.'.format(col_mean_name,self.targetName, np.corrcoef(X[self.targetName].values, encoded_feature)[0][1]))
        if self.discardOriginal_col:
            X = X.drop(self.targetName, axis=1)
        return X

class KFoldTargetEncoderTest(base.BaseEstimator, base.TransformerMixin):
    
    def __init__(self,train,colNames,encodedName):
        
        self.train = train
        self.colNames = colNames
        self.encodedName = encodedName
        
    def fit(self, X, y=None):
        return self
    def transform(self,X):
        mean =  self.train[[self.colNames,
                self.encodedName]].groupby(
                                self.colNames).mean().reset_index() 
        
        dd = {}
        for index, row in mean.iterrows():
            dd[row[self.colNames]] = row[self.encodedName]
        X[self.encodedName] = X[self.colNames]
        X = X.replace({self.encodedName: dd})
        return X

# %%
from scipy.stats.mstats import winsorize
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('dark_background')
# %matplotlib inline

import os
import time
import datetime
import random
import multiprocessing
import pickle

import scipy.stats

import gc
gc.enable()

import warnings
warnings.filterwarnings('ignore')


from sklearn.model_selection import KFold, StratifiedKFold, GroupKFold
from sklearn.preprocessing import RobustScaler, LabelEncoder
from sklearn.metrics import log_loss, roc_auc_score, confusion_matrix
from sklearn.neighbors import KNeighborsClassifier
#from sklearn.impute import SimpleImputer
from imblearn.over_sampling import SMOTE

import lightgbm as lgb

# %%
############ RANDOMNESS

# seed function
def seed_everything(seed = 42):
    os.environ['PYTHONHASHSEED'] = str(seed)
    random.seed(seed)
    np.random.seed(seed)
    
# set seed
seed = 42
seed_everything(seed)

# %% [markdown]
# ### IMPORT

# %%
############ DATA IMPORT

# id data
train = pd.read_csv('../raw/training.csv')
test  = pd.read_csv('../raw/unlabeled.csv')


# check dimensions
print(train.shape)
print(test.shape)

train = train[-train['hospital_death'].isnull()]
# Out:
# (110369, 186)
# (39308, 186)

# %%
train = reduce_mem_usage(train)
test  = reduce_mem_usage(test)
# Out:
# Mem. usage decreased to 37.78 Mb (71.1% reduction)
# Mem. usage decreased to 16.01 Mb (71.3% reduction)

# %%
train['NAs'] = train.isnull().sum(axis=1)
test['NAs']  = test.isnull().sum(axis=1)

# %%
y     = train['hospital_death']
train = train.drop('hospital_death', axis=1)

# %% [markdown]
# train['conditions'] = train[['aids',
#  'cirrhosis',
#  'diabetes_mellitus',
#  'hepatic_failure',
#  'immunosuppression',
#  'leukemia',
#  'lymphoma',
#  'solid_tumor_with_metastasis']].sum(axis=1)
#
# test['conditions'] = test[['aids',
#  'cirrhosis',
#  'diabetes_mellitus',
#  'hepatic_failure',
#  'immunosuppression',
#  'leukemia',
#  'lymphoma',
#  'solid_tumor_with_metastasis']].sum(axis=1)

# %%
train['apache_4a_hospital_death_prob'][train['apache_4a_hospital_death_prob']==-1] = np.nan
test['apache_4a_hospital_death_prob'][test['apache_4a_hospital_death_prob']==-1]   = np.nan

train['apache_4a_icu_death_prob'][train['apache_4a_icu_death_prob']==-1] = np.nan
test['apache_4a_icu_death_prob'][test['apache_4a_icu_death_prob']==-1]   = np.nan

# %%
train = train.replace([np.inf, -np.inf], np.nan)
test  = test.replace([np.inf, -np.inf], np.nan)

# %%
train[train['pre_icu_los_days']<0]['pre_icu_los_days'] = 0
test[test['pre_icu_los_days']<0]['pre_icu_los_days'] = 0

# %%
train['apache_prob_prod'] = train['apache_4a_hospital_death_prob'] * train[ 'apache_4a_icu_death_prob']
test['apache_prob_prod'] = test['apache_4a_hospital_death_prob'] * train[ 'apache_4a_icu_death_prob']

# %%
excluded_feats = ['encounter_id', 'patient_id', 'readmission_status']#, 'hospital_id', 'icu_id', 'icu_type']

# %%
train['hospital_id'] = train['hospital_id'].astype('object')
test['hospital_id']  = test['hospital_id'].astype('object')

train['icu_id'] = train['icu_id'].astype('object')
test['icu_id']  = test['icu_id'].astype('object')

# %%
train['age_factor'] = 0
train.loc[train['age']<10, 'age_factor'] = 'under_10'
train.loc[((train['age']>10) & (train['age']<20)), 'age_factor'] = 'b_10_20'
train.loc[((train['age']>20) & (train['age']<35)), 'age_factor'] = 'b_20_35'
train.loc[((train['age']>35) & (train['age']<50)), 'age_factor'] = 'b_35_50'
train.loc[((train['age']>50) & (train['age']<70)), 'age_factor'] = 'b_50_70'
train.loc[train['age']>70, 'age_factor'] = 'above_70'

test['age_factor'] = 0
test.loc[test['age']<10, 'age_factor'] = 'under_10'
test.loc[((test['age']>10) & (train['age']<20)), 'age_factor'] = 'b_10_20'
test.loc[((test['age']>20) & (train['age']<35)), 'age_factor'] = 'b_20_35'
test.loc[((test['age']>35) & (train['age']<50)), 'age_factor'] = 'b_35_50'
test.loc[((test['age']>50) & (train['age']<70)), 'age_factor'] = 'b_50_70'
test.loc[test['age']>70, 'age_factor'] = 'above_70'

# %%
def mbp_risk1(train):

    """Categorises whether blood pressure is elevated, 
 stage 1 hypertension or stage 2 hypertension"""
    if train['d1_mbp_noninvasive_max'] >= 120 and train['d1_mbp_noninvasive_max'] < 130 and train['d1_mbp_noninvasive_min'] < 80:
        bprisk = 'elevated BP'
    elif (train['d1_mbp_noninvasive_max'] >= 130 and train['d1_mbp_noninvasive_max'] < 140) or (train['d1_mbp_noninvasive_min'] >= 80 and train['d1_mbp_noninvasive_min']< 90):
        bprisk = 'stage 1 hypertension'
    elif train['d1_mbp_noninvasive_max'] >= 140 or train['d1_mbp_noninvasive_min'] >= 90:
         bprisk = 'stage 2 hypertension'
    else:
        bprisk = 'NAN'
    return bprisk

def mbp_risk2(train):

    """Categorises whether blood pressure is elevated, 
 stage 1 hypertension or stage 2 hypertension"""
    if train['d1_mbp_max'] >= 120 and train['d1_mbp_max'] < 130 and train['d1_mbp_min'] < 80:
        bprisk = 'elevated BP'
    elif (train['d1_mbp_max'] >= 130 and train['d1_mbp_max'] < 140) or (train['d1_mbp_min'] >= 80 and train['d1_mbp_min']< 90):
        bprisk = 'stage 1 hypertension'
    elif train['d1_mbp_max'] >= 140 or train['d1_mbp_min'] >= 90:
         bprisk = 'stage 2 hypertension'
    else:
        bprisk = 'NAN'
    return bprisk

def mbp_risk3(train):

    """Categorises whether blood pressure is elevated, 
 stage 1 hypertension or stage 2 hypertension"""
    if train['d1_mbp_invasive_max'] >= 120 and train['d1_mbp_invasive_max'] < 130 and train['d1_mbp_invasive_min'] < 80:
        bprisk = 'elevated BP'
    elif (train['d1_mbp_invasive_max'] >= 130 and train['d1_mbp_invasive_max'] < 140) or (train['d1_mbp_invasive_min'] >= 80 and train['d1_mbp_invasive_min']< 90):
        bprisk = 'stage 1 hypertension'
    elif train['d1_mbp_invasive_max'] >= 140 or train['d1_mbp_invasive_min'] >= 90:
         bprisk = 'stage 2 hypertension'
    else:
        bprisk = 'NAN'
    return bprisk

# %%
X1 = 12
Y1 =16

def resprate_min_resp_classt(num):
    if pd.isna(num):
        return np.nan
    if X1 <= num <= Y1:
        return 'normal'
    elif num <= 12:
        return 'below normal'
    elif num >= 16: 
        return 'above normal'
    
X2= 12
Y2 =16

def resprate_max_classt(num):
    if pd.isna(num):
        return np.nan
    if X2 <= num <= Y2:
        return 'normal'
    elif num <= 12:
        return 'below normal'
    elif num >= 16: 
        return 'above normal'
    
X = 36.5
Y =37.5

def temp_classt(num):
    if pd.isna(num):
        return np.nan
    if X <= num <= Y:
        return 'normal'
    elif num <= 36.4:
        return 'below normal'
    elif num >= 37.6: 
        return 'above normal'
    
def weighted_classt(x): 
    if pd.isna(x):
        return np.nan
    elif x < 15: 
        return 'very severely underweight' 
    elif x >= 15 and x < 16: 
        return 'severely weight' 
    elif x >=16 and x < 18.5: 
        return 'underweight' 
    elif x >= 18.5 and x < 25: 
        return 'healthy weight' 
    elif x >= 25 and x < 30: 
        return 'overweight'
    elif x >= 30 and x < 35: 
        return 'class 1' 
    elif x >= 35 and x < 40: 
        return 'class 2' 
    else: 
        return 'class 3' 
 
    
    
train['resprate_min'] = train['d1_resprate_min'].map(resprate_min_resp_classt)
test['resprate_min'] = test['d1_resprate_min'].map(resprate_min_resp_classt)
train['resprate_max'] = train['d1_resprate_max'].map(resprate_max_classt)
test['resprate_max'] = test['d1_resprate_max'].map(resprate_max_classt)
train['temp_class'] = train['temp_apache'].map(temp_classt)
test['temp_class'] = test['temp_apache'].map(temp_classt)
train['weightclass'] = train['bmi'].map(weighted_classt)
test['weightclass'] = test['bmi'].map(weighted_classt)
train['mean_reperate'] = train['d1_resprate_min'] + (train['d1_resprate_min']/2)
test['mean_reperate'] = test['d1_resprate_min']+ (test['d1_resprate_min']/2)

# %% [markdown]
# def sodium_apache_classt(x):
#     if pd.isna(x):
#         return np.nan
#     elif x < 120:
#         return "Very low"
#     elif x >= 120 and x < 134:
#         return 'Low Abnormal Range'
#     elif x >=135 and x < 154:
#         return 'Normal Range'
#     elif x >= 155:
#         return 'High Abnoral Range'
# train['sodium_apache_classt'] = train['sodium_apache'].apply(sodium_apache_classt)
# test['sodium_apache_classt'] = test['sodium_apache'].apply(sodium_apache_classt)
#
# def albumin_apache_classt(x):
#     if pd.isna(x):
#         return np.nan
#     elif x < 20 :
#         return "Very low"
#     elif x >= 20 and x <= 24:
#         return  "low"
#     elif x >=25 and x <= 44:
#         return "Normal"
#     elif x >= 45:
#         return "High"
# train['albumin_apache_classt'] = train['albumin_apache'].apply(albumin_apache_classt)
# test['albumin_apache_classt'] = test['albumin_apache'].apply(albumin_apache_classt)
# def potassium_classt(x):
#     if pd.isna(x):
#         return np.nan
#     elif x < 2.5:
#         return "Very Low"
#     elif x >= 2.5 and x <= 3.4:
#         return 'Low Abnormal Range'
#     elif x >=3.5 and x <= 5.4:
#         return 'Normal Range'
#     elif x >= 5.5 and x <=7 :
#         return 'High Abnoral Range'
# train['potassium_min_classt'] = train['d1_potassium_min'].apply(potassium_classt)
# test['potassium_min_classt'] = test['d1_potassium_min'].apply(potassium_classt)

# %%
for column in ['d1_diasbp_invasive', 'd1_diasbp', 'd1_diasbp_noninvasive', 'd1_heartrate','d1_mbp_invasive',
              'd1_mbp', 'd1_mbp_noninvasive', 'd1_resprate', 'd1_spo2', 'd1_sysbp_invasive', 'd1_sysbp',
              'd1_sysbp_noninvasive', 'd1_temp', 'h1_diasbp_invasive', 'h1_diasbp', 'h1_diasbp_noninvasive',
              'h1_heartrate', 'h1_mbp_invasive', 'h1_mbp', 'h1_mbp_noninvasive', 'h1_resprate', 'h1_spo2',
              'h1_sysbp_invasive', 'h1_sysbp', 'h1_sysbp_noninvasive', 'h1_temp', 'd1_albumin',
              'd1_bilirubin', 'd1_bun', 'd1_calcium', 'd1_creatinine', 'd1_glucose', 'd1_hco3',
              'd1_hemaglobin', 'd1_hematocrit', 'd1_inr', 'd1_lactate', 'd1_platelets', 'd1_potassium',
              'd1_sodium', 'd1_wbc', 'h1_albumin', 'h1_bilirubin', 'h1_bun', 'h1_calcium',
              'h1_creatinine', 'h1_glucose', 'h1_hco3', 'h1_hemaglobin', 'h1_hematocrit', 'h1_inr',
              'h1_lactate', 'h1_platelets', 'h1_potassium', 'h1_sodium', 'h1_wbc', 'd1_arterial_pco2',
              'd1_arterial_ph', 'd1_arterial_po2', 'd1_pao2fio2ratio', 'h1_arterial_pco2',
              'h1_arterial_ph', 'h1_pao2fio2ratio']:
    
    train[f'{column}_span'] = train[f'{column}_max'] - train[f'{column}_min']
    test[f'{column}_span'] = test[f'{column}_max'] - test[f'{column}_min']

# %%
def max_classt(row):
    if pd.isna(row):
        return np.nan
    elif (row<50):
        return 0
    elif ((row>=50) and (row<70)):
        return 1
    elif ((row>=70) and (row<80)):
        return 2
    elif ((row>=80) and (row<100)):
        return 3
    elif ((row>=100) and (row<250)):
        return 4
    elif ((row>=250) and (row<350)):
        return 5
    elif ((row>350) and (row<500)):
        return 6
    elif ((row>=500)):
        return 7

# %% [markdown]
# train['h1_pao2fio2ratio_max_classt'] = train['h1_pao2fio2ratio_max'].apply(max_classt)
# test['h1_pao2fio2ratio_max_classt'] = test['h1_pao2fio2ratio_max'].apply(max_classt)
#
# train['h1_pao2fio2ratio_min_classt'] = train['h1_pao2fio2ratio_min'].apply(max_classt)
# test['h1_pao2fio2ratio_min_classt'] = test['h1_pao2fio2ratio_min'].apply(max_classt)
#
# train['d1_pao2fio2ratio_max_classt'] = train['d1_pao2fio2ratio_max'].apply(max_classt)
# test['d1_pao2fio2ratio_max_classt'] = test['d1_pao2fio2ratio_max'].apply(max_classt)
#
# train['d1_pao2fio2ratio_min_classt'] = train['d1_pao2fio2ratio_min'].apply(max_classt)
# test['d1_pao2fio2ratio_min_classt'] = test['d1_pao2fio2ratio_min'].apply(max_classt)

# %%
nulls = pd.DataFrame(train.isnull().sum(axis=0))
excluded_feats.extend(list(nulls[nulls[0]>70000].index))

# %%
features = [f for f in train.columns if f not in excluded_feats]

# %%
############ PARAMETERS

# cores
cores = 20
# cross-validation
num_folds = 10
shuffle   = True

seed = 111

# number of trees
max_rounds = 10000
stopping   = 400
verbose    = 250

# LGB parameters
lgb_params = {
    'boosting_type':     'gbdt',
    'objective':         'binary',
    'metric':            'auc',
    'bagging_fraction':  0.5,
    'feature_fraction':  0.5,
    'lambda_l1':         0.1,
    'lambda_l2':         0.5,
    'min_split_gain':    0.1,
    'min_child_weight':  0,
    'min_child_samples': 10,
    'silent':            True,
    'verbosity':         -1,
    'learning_rate':     0.01,
    'max_depth':         5,
    'num_leaves':        64,
    'scale_pos_weight':  1,
    'n_estimators':      max_rounds,
    'nthread' :          cores,
    'random_state':      seed,
    #"device" : "gpu"
}

# data partitinoing
folds = StratifiedKFold(n_splits = num_folds, random_state = seed, shuffle = shuffle)

# %%
############ PLACEHOLDERS

# placeholders
clfs = []
importances = pd.DataFrame()

# predictions
preds_test   = np.zeros(test.shape[0])
preds_oof    = np.zeros(train.shape[0])

# %%
############ CROSS-VALIDATION LOOP
cv_start  = time.time()
for n_fold, (trn_idx, val_idx) in enumerate(folds.split(train, y)):

    # data partitioning
    trn_x, trn_y = train[features].iloc[trn_idx], y.iloc[trn_idx]
    val_x, val_y = train[features].iloc[val_idx], y.iloc[val_idx]
    test_x       = test[features]
    
        
    # Fill Na
    for feature in ['ethnicity', 'gender']:
      trn_x[feature]  = trn_x[feature].fillna(trn_x[feature].mode()[0])
      val_x[feature]  = val_x[feature].fillna(trn_x[feature].mode()[0])
      test_x[feature] = test_x[feature].fillna(trn_x[feature].mode()[0])

    for feature in ['hospital_admit_source', 'icu_admit_source', 'icu_stay_type']:#, 'icu_type']:
      trn_x[feature]  = trn_x[feature].fillna('missing')
      val_x[feature]  = val_x[feature].fillna('missing')
      test_x[feature] = test_x[feature].fillna('missing')
    
    trn_x = pd.concat([trn_x, trn_y], axis=1)
    val_x = pd.concat([val_x, val_y], axis=1)
    
    for feature in trn_x.select_dtypes('object').columns:    
        targetc = KFoldTargetEncoderTrain(feature,'hospital_death',n_fold=10)
        trn_x = targetc.fit_transform(trn_x)

        test_targetc = KFoldTargetEncoderTest(trn_x,
                                              feature,
                                              f'{feature}_Kfold_Target_Enc')
        test_x = test_targetc.fit_transform(test_x)
        
        val_targetc = KFoldTargetEncoderTest(trn_x,
                                              feature,
                                              f'{feature}_Kfold_Target_Enc')
        val_x = val_targetc.fit_transform(val_x)
    
        
    
    trn_y = trn_x['hospital_death']
    trn_x = trn_x.drop('hospital_death', axis=1)
    
    val_y = val_x['hospital_death']
    val_x = val_x.drop('hospital_death', axis=1)
    

    for column in trn_x.select_dtypes('object').columns:
        trn_x[column] = trn_x[column].fillna('')
        val_x[column] = val_x[column].fillna('')
        test_x[column] = test_x[column].fillna('')
        

    for column in ['urineoutput_apache','lymphoma', 'd1_potassium_min',
                  'd1_heartrate_min', 'd1_mbp_noninvasive_max', 
                  'd1_creatinine_min' , 'd1_platelets_min']:
        trn_x[f'{column}_given'] = trn_x[column].isna()
        val_x[f'{column}_given'] = val_x[column].isna()
        test_x[f'{column}_given'] = test_x[column].isna()
        
        
    # label encoding
    trn_x, val_x, test_x = label_encoding(trn_x, val_x, test_x)
       
    ## add noise to train to reduce overfitting
    trn_x += np.random.normal(0, 0.1, trn_x.shape)
    
    # print data dimensions
    print('Data shape:', trn_x.shape, val_x.shape)
    #print('Data shape:', trn_y.shape, val_y.shape)    
    # train lightGBM
    clf = lgb.LGBMClassifier(**lgb_params) 
    clf = clf.fit(trn_x, trn_y, 
                  eval_set              = [(trn_x, trn_y), (val_x, val_y)], 
                  eval_metric           = 'auc', 
                  early_stopping_rounds = stopping,
                  verbose               = verbose)
    clfs.append(clf)
    
    # find the best iteration
    best_iter = clf.best_iteration_

    # save predictions
    preds_oof[val_idx] = clf.predict_proba(val_x,  num_iteration = best_iter)[:, 1]
    preds_test        += clf.predict_proba(test_x, num_iteration = best_iter)[:, 1] / folds.n_splits 

    # importance
    fold_importance_df               = pd.DataFrame()
    fold_importance_df['Feature']    = trn_x.columns
    fold_importance_df['Importance'] = clf.feature_importances_
    fold_importance_df['Fold']       = n_fold + 1
    importances                      = pd.concat([importances, fold_importance_df], axis = 0)
    
    # print performance
    print('--------------------------------')
    print('FOLD%2d: AUC = %.6f' % (n_fold + 1, roc_auc_score(y[val_idx], preds_oof[val_idx])))
    print('--------------------------------')
    print('')
        
    # clear memory
    del trn_x, trn_y, val_x, val_y
    gc.collect()
    
    
# print overall performance    
cv_perf = roc_auc_score(y, preds_oof)
print('--------------------------------')
print('- OOF AUC = %.6f' % cv_perf)
print('- CV TIME = {:.2f} min'.format((time.time() - cv_start) / 60))
print('--------------------------------')
# Out:
# Correlation between the new feature, hospital_id_Kfold_Target_Enc and, hospital_death is 0.03269393850053638.
# Correlation between the new feature, ethnicity_Kfold_Target_Enc and, hospital_death is -0.028260843510362073.
# Correlation between the new feature, gender_Kfold_Target_Enc and, hospital_death is -0.029968692951016104.
# Correlation between the new feature, hospital_admit_source_Kfold_Target_Enc and, hospital_death is 0.0950020361992956.
# Correlation between the new feature, icu_admit_source_Kfold_Target_Enc and, hospital_death is 0.10744825680871012.
# Correlation between the new feature, icu_id_Kfold_Target_Enc and, hospital_death is 0.04706453264072775.
# Correlation between the new feature, icu_stay_type_Kfold_Target_Enc and, hospital_death is -0.005314139037831214.
# Correlation between the new feature, icu_type_Kfold_Target_Enc and, hospital_death is 0.038097378666727334.
# Correlation between the new feature, apache_3j_bodysystem_Kfold_Target_Enc and, hospital_death is 0.11922149368146844.
# Correlation between the new feature, apache_2_bodysystem_Kfold_Target_Enc and, hospital_death is 0.10303327468643929.
# Correlation between the new feature, age_factor_Kfold_Target_Enc and, hospital_death is 0.0980783795512431.
# Correlation between the new feature, resprate_min_Kfold_Target_Enc and, hospital_death is 0.06287014537659953.
# Correlation between the new feature, resprate_max_Kfold_Target_Enc and, hospital_death is -0.0144750617306641.
# Correlation between the new feature, temp_class_Kfold_Target_Enc and, hospital_death is 0.07653534528588732.
# Correlation between the new feature, weightclass_Kfold_Target_Enc and, hospital_death is 0.025849415729605082.
# Data shape: (82541, 212) (9172, 212)
# Training until validation scores don't improve for 400 rounds
# [250]	training's auc: 0.908511	valid_1's auc: 0.89498
# [500]	training's auc: 0.923589	valid_1's auc: 0.901444
# [750]	training's auc: 0.934534	valid_1's auc: 0.904518
# [1000]	training's auc: 0.942571	valid_1's auc: 0.906229
# [1250]	training's auc: 0.949533	valid_1's auc: 0.907349
# [1500]	training's auc: 0.955497	valid_1's auc: 0.908047
# [1750]	training's auc: 0.960614	valid_1's auc: 0.908463
# [2000]	training's auc: 0.96534	valid_1's auc: 0.908673
# [2250]	training's auc: 0.969335	valid_1's auc: 0.908883
# [2500]	training's auc: 0.973198	valid_1's auc: 0.909205
# [2750]	training's auc: 0.976535	valid_1's auc: 0.909348
# [3000]	training's auc: 0.979573	valid_1's auc: 0.909535
# [3250]	training's auc: 0.982132	valid_1's auc: 0.909764
# [3500]	training's auc: 0.984514	valid_1's auc: 0.909843
# [3750]	training's auc: 0.986539	valid_1's auc: 0.909845
# Early stopping, best iteration is:
# [3373]	training's auc: 0.983325	valid_1's auc: 0.909878
# --------------------------------
# FOLD 1: AUC = 0.909878
# --------------------------------
#
# Correlation between the new feature, hospital_id_Kfold_Target_Enc and, hospital_death is 0.0330786555153711.
# Correlation between the new feature, ethnicity_Kfold_Target_Enc and, hospital_death is -0.022346466491846143.
# Correlation between the new feature, gender_Kfold_Target_Enc and, hospital_death is -0.021696962881925533.
# Correlation between the new feature, hospital_admit_source_Kfold_Target_Enc and, hospital_death is 0.09380787822349566.
# Correlation between the new feature, icu_admit_source_Kfold_Target_Enc and, hospital_death is 0.10696636797177592.
# Correlation between the new feature, icu_id_Kfold_Target_Enc and, hospital_death is 0.047135860162955984.
# Correlation between the new feature, icu_stay_type_Kfold_Target_Enc and, hospital_death is 0.0021589212541410635.
# Correlation between the new feature, icu_type_Kfold_Target_Enc and, hospital_death is 0.03889310864266806.
# Correlation between the new feature, apache_3j_bodysystem_Kfold_Target_Enc and, hospital_death is 0.11743995472300024.
# Correlation between the new feature, apache_2_bodysystem_Kfold_Target_Enc and, hospital_death is 0.10127650747365524.
# Correlation between the new feature, age_factor_Kfold_Target_Enc and, hospital_death is 0.09697538727435005.
# Correlation between the new feature, resprate_min_Kfold_Target_Enc and, hospital_death is 0.06574338801520864.
# Correlation between the new feature, resprate_max_Kfold_Target_Enc and, hospital_death is -0.008600280843374124.
# Correlation between the new feature, temp_class_Kfold_Target_Enc and, hospital_death is 0.07923959664476253.
# Correlation between the new feature, weightclass_Kfold_Target_Enc and, hospital_death is 0.028563035228678337.
# Data shape: (82541, 212) (9172, 212)
# Training until validation scores don't improve for 400 rounds
# [250]	training's auc: 0.907604	valid_1's auc: 0.897588
# [500]	training's auc: 0.923154	valid_1's auc: 0.903893
# [750]	training's auc: 0.93358	valid_1's auc: 0.906823
# [1000]	training's auc: 0.941891	valid_1's auc: 0.908496
# [1250]	training's auc: 0.949082	valid_1's auc: 0.909234
# [1500]	training's auc: 0.955521	valid_1's auc: 0.909689
# [1750]	training's auc: 0.961285	valid_1's auc: 0.910026
# [2000]	training's auc: 0.965962	valid_1's auc: 0.91021
# [2250]	training's auc: 0.970244	valid_1's auc: 0.910513
# [2500]	training's auc: 0.973951	valid_1's auc: 0.910719
# [2750]	training's auc: 0.977091	valid_1's auc: 0.910935
# [3000]	training's auc: 0.979927	valid_1's auc: 0.911
# [3250]	training's auc: 0.982491	valid_1's auc: 0.910891
# Early stopping, best iteration is:
# [3000]	training's auc: 0.979927	valid_1's auc: 0.911
# --------------------------------
# FOLD 2: AUC = 0.911000
# --------------------------------
#
# Correlation between the new feature, hospital_id_Kfold_Target_Enc and, hospital_death is 0.033921379412580416.
# Correlation between the new feature, ethnicity_Kfold_Target_Enc and, hospital_death is -0.0178707606823555.
# Correlation between the new feature, gender_Kfold_Target_Enc and, hospital_death is -0.02506003463739456.
# Correlation between the new feature, hospital_admit_source_Kfold_Target_Enc and, hospital_death is 0.09501912675214208.
# Correlation between the new feature, icu_admit_source_Kfold_Target_Enc and, hospital_death is 0.1063817568000637.
# Correlation between the new feature, icu_id_Kfold_Target_Enc and, hospital_death is 0.047183205128577585.
# Correlation between the new feature, icu_stay_type_Kfold_Target_Enc and, hospital_death is 0.0015903314837239309.
# Correlation between the new feature, icu_type_Kfold_Target_Enc and, hospital_death is 0.03785007936351534.
# Correlation between the new feature, apache_3j_bodysystem_Kfold_Target_Enc and, hospital_death is 0.11623277088405025.
# Correlation between the new feature, apache_2_bodysystem_Kfold_Target_Enc and, hospital_death is 0.09967720820752539.
# Correlation between the new feature, age_factor_Kfold_Target_Enc and, hospital_death is 0.09954373836640586.
# Correlation between the new feature, resprate_min_Kfold_Target_Enc and, hospital_death is 0.06256059948368418.
# Correlation between the new feature, resprate_max_Kfold_Target_Enc and, hospital_death is -0.013473257341321114.
# Correlation between the new feature, temp_class_Kfold_Target_Enc and, hospital_death is 0.0766619687493643.
# Correlation between the new feature, weightclass_Kfold_Target_Enc and, hospital_death is 0.02833791479610905.
# Data shape: (82541, 212) (9172, 212)
# Training until validation scores don't improve for 400 rounds
# [250]	training's auc: 0.90891	valid_1's auc: 0.89472
# [500]	training's auc: 0.924024	valid_1's auc: 0.901606
# [750]	training's auc: 0.934361	valid_1's auc: 0.905068
# [1000]	training's auc: 0.942184	valid_1's auc: 0.90655
# [1250]	training's auc: 0.949397	valid_1's auc: 0.907798
# [1500]	training's auc: 0.955824	valid_1's auc: 0.908454
# [1750]	training's auc: 0.961154	valid_1's auc: 0.908808
# [2000]	training's auc: 0.965886	valid_1's auc: 0.909194
# [2250]	training's auc: 0.970001	valid_1's auc: 0.909352
# [2500]	training's auc: 0.973846	valid_1's auc: 0.909395
# [2750]	training's auc: 0.977234	valid_1's auc: 0.909511
# [3000]	training's auc: 0.980244	valid_1's auc: 0.909422
# Early stopping, best iteration is:
# [2837]	training's auc: 0.978258	valid_1's auc: 0.909526
# --------------------------------
# FOLD 3: AUC = 0.909526
# --------------------------------
#
# Correlation between the new feature, hospital_id_Kfold_Target_Enc and, hospital_death is 0.03433097753577323.
# Correlation between the new feature, ethnicity_Kfold_Target_Enc and, hospital_death is -0.01758711950402444.
# Correlation between the new feature, gender_Kfold_Target_Enc and, hospital_death is -0.031184161610878627.
# Correlation between the new feature, hospital_admit_source_Kfold_Target_Enc and, hospital_death is 0.09513459510429885.
# Correlation between the new feature, icu_admit_source_Kfold_Target_Enc and, hospital_death is 0.10724688579260967.
# Correlation between the new feature, icu_id_Kfold_Target_Enc and, hospital_death is 0.04845631741046564.
# Correlation between the new feature, icu_stay_type_Kfold_Target_Enc and, hospital_death is 0.00042930325867952113.
# Correlation between the new feature, icu_type_Kfold_Target_Enc and, hospital_death is 0.03933407723451548.
# Correlation between the new feature, apache_3j_bodysystem_Kfold_Target_Enc and, hospital_death is 0.11917467570857278.
# Correlation between the new feature, apache_2_bodysystem_Kfold_Target_Enc and, hospital_death is 0.10093610817492794.
# Correlation between the new feature, age_factor_Kfold_Target_Enc and, hospital_death is 0.0981912804047249.
# Correlation between the new feature, resprate_min_Kfold_Target_Enc and, hospital_death is 0.06588605762108414.
# Correlation between the new feature, resprate_max_Kfold_Target_Enc and, hospital_death is -0.011751478022479844.
# Correlation between the new feature, temp_class_Kfold_Target_Enc and, hospital_death is 0.08093308070322622.
# Correlation between the new feature, weightclass_Kfold_Target_Enc and, hospital_death is 0.026793999118854016.
# Data shape: (82542, 212) (9171, 212)
# Training until validation scores don't improve for 400 rounds
# [250]	training's auc: 0.908332	valid_1's auc: 0.891396
# [500]	training's auc: 0.923493	valid_1's auc: 0.899742
# [750]	training's auc: 0.934061	valid_1's auc: 0.904048
# [1000]	training's auc: 0.942409	valid_1's auc: 0.906299
# [1250]	training's auc: 0.9498	valid_1's auc: 0.907621
# [1500]	training's auc: 0.955935	valid_1's auc: 0.908413
# [1750]	training's auc: 0.961025	valid_1's auc: 0.908813
# [2000]	training's auc: 0.965353	valid_1's auc: 0.909195
# [2250]	training's auc: 0.969243	valid_1's auc: 0.909195
# Early stopping, best iteration is:
# [1908]	training's auc: 0.963742	valid_1's auc: 0.909243
# --------------------------------
# FOLD 4: AUC = 0.909243
# --------------------------------
#
# Correlation between the new feature, hospital_id_Kfold_Target_Enc and, hospital_death is 0.03302644052619018.
# Correlation between the new feature, ethnicity_Kfold_Target_Enc and, hospital_death is -0.0243165756417671.
# Correlation between the new feature, gender_Kfold_Target_Enc and, hospital_death is -0.02167423359669503.
# Correlation between the new feature, hospital_admit_source_Kfold_Target_Enc and, hospital_death is 0.09414789331929081.
# Correlation between the new feature, icu_admit_source_Kfold_Target_Enc and, hospital_death is 0.10625439033821751.
# Correlation between the new feature, icu_id_Kfold_Target_Enc and, hospital_death is 0.04637604723971586.
# Correlation between the new feature, icu_stay_type_Kfold_Target_Enc and, hospital_death is -0.0019448316560991667.
# Correlation between the new feature, icu_type_Kfold_Target_Enc and, hospital_death is 0.03847510121319355.
# Correlation between the new feature, apache_3j_bodysystem_Kfold_Target_Enc and, hospital_death is 0.11818037695497184.
# Correlation between the new feature, apache_2_bodysystem_Kfold_Target_Enc and, hospital_death is 0.10149044973690999.
# Correlation between the new feature, age_factor_Kfold_Target_Enc and, hospital_death is 0.0980071282483798.
# Correlation between the new feature, resprate_min_Kfold_Target_Enc and, hospital_death is 0.06677525553873917.
# Correlation between the new feature, resprate_max_Kfold_Target_Enc and, hospital_death is -0.013102598285213604.
# Correlation between the new feature, temp_class_Kfold_Target_Enc and, hospital_death is 0.07632703625064129.
# Correlation between the new feature, weightclass_Kfold_Target_Enc and, hospital_death is 0.025775203376875666.
# Data shape: (82542, 212) (9171, 212)
# Training until validation scores don't improve for 400 rounds
# [250]	training's auc: 0.908594	valid_1's auc: 0.895323
# [500]	training's auc: 0.923937	valid_1's auc: 0.901362
# [750]	training's auc: 0.934356	valid_1's auc: 0.904869
# [1000]	training's auc: 0.942807	valid_1's auc: 0.906752
# [1250]	training's auc: 0.950142	valid_1's auc: 0.908085
# [1500]	training's auc: 0.956072	valid_1's auc: 0.908711
# [1750]	training's auc: 0.961184	valid_1's auc: 0.909149
# [2000]	training's auc: 0.96563	valid_1's auc: 0.909475
# [2250]	training's auc: 0.96986	valid_1's auc: 0.909723
# [2500]	training's auc: 0.973513	valid_1's auc: 0.909992
# [2750]	training's auc: 0.976762	valid_1's auc: 0.910199
# [3000]	training's auc: 0.979544	valid_1's auc: 0.9101
# Early stopping, best iteration is:
# [2765]	training's auc: 0.976924	valid_1's auc: 0.910218
# --------------------------------
# FOLD 5: AUC = 0.910218
# --------------------------------
#
# Correlation between the new feature, hospital_id_Kfold_Target_Enc and, hospital_death is 0.030314977291489475.
# Correlation between the new feature, ethnicity_Kfold_Target_Enc and, hospital_death is -0.027048852117590227.
# Correlation between the new feature, gender_Kfold_Target_Enc and, hospital_death is -0.02377974690894577.
# Correlation between the new feature, hospital_admit_source_Kfold_Target_Enc and, hospital_death is 0.09642049167525163.
# Correlation between the new feature, icu_admit_source_Kfold_Target_Enc and, hospital_death is 0.10929798467947163.
# Correlation between the new feature, icu_id_Kfold_Target_Enc and, hospital_death is 0.043302363933680255.
# Correlation between the new feature, icu_stay_type_Kfold_Target_Enc and, hospital_death is -0.0014127324400785126.
# Correlation between the new feature, icu_type_Kfold_Target_Enc and, hospital_death is 0.037676613947869385.
# Correlation between the new feature, apache_3j_bodysystem_Kfold_Target_Enc and, hospital_death is 0.11834498197994144.
# Correlation between the new feature, apache_2_bodysystem_Kfold_Target_Enc and, hospital_death is 0.10084052642122102.
# Correlation between the new feature, age_factor_Kfold_Target_Enc and, hospital_death is 0.09785200908453066.
# Correlation between the new feature, resprate_min_Kfold_Target_Enc and, hospital_death is 0.06684049039695271.
# Correlation between the new feature, resprate_max_Kfold_Target_Enc and, hospital_death is -0.013515351777572225.
# Correlation between the new feature, temp_class_Kfold_Target_Enc and, hospital_death is 0.07866360089826645.
# Correlation between the new feature, weightclass_Kfold_Target_Enc and, hospital_death is 0.02399278786629023.
# Data shape: (82542, 212) (9171, 212)
# Training until validation scores don't improve for 400 rounds
# [250]	training's auc: 0.908108	valid_1's auc: 0.890273
# [500]	training's auc: 0.923467	valid_1's auc: 0.898623
# [750]	training's auc: 0.934132	valid_1's auc: 0.902057
# [1000]	training's auc: 0.9423	valid_1's auc: 0.904232
# [1250]	training's auc: 0.949681	valid_1's auc: 0.905433
# [1500]	training's auc: 0.955822	valid_1's auc: 0.906214
# [1750]	training's auc: 0.960935	valid_1's auc: 0.906699
# [2000]	training's auc: 0.965397	valid_1's auc: 0.906922
# [2250]	training's auc: 0.969528	valid_1's auc: 0.907186
# [2500]	training's auc: 0.973201	valid_1's auc: 0.907286
# [2750]	training's auc: 0.976429	valid_1's auc: 0.907414
# [3000]	training's auc: 0.979543	valid_1's auc: 0.90758
# [3250]	training's auc: 0.982222	valid_1's auc: 0.90753
# Early stopping, best iteration is:
# [2984]	training's auc: 0.979382	valid_1's auc: 0.907604
# --------------------------------
# FOLD 6: AUC = 0.907604
# --------------------------------
#
# Correlation between the new feature, hospital_id_Kfold_Target_Enc and, hospital_death is 0.02765695912087288.
# Correlation between the new feature, ethnicity_Kfold_Target_Enc and, hospital_death is -0.01693245403785041.
# Correlation between the new feature, gender_Kfold_Target_Enc and, hospital_death is -0.022360582219397716.
# Correlation between the new feature, hospital_admit_source_Kfold_Target_Enc and, hospital_death is 0.09662476123147008.
# Correlation between the new feature, icu_admit_source_Kfold_Target_Enc and, hospital_death is 0.10694968262386857.
# Correlation between the new feature, icu_id_Kfold_Target_Enc and, hospital_death is 0.042608527796587525.
# Correlation between the new feature, icu_stay_type_Kfold_Target_Enc and, hospital_death is -0.0030458322919705676.
# Correlation between the new feature, icu_type_Kfold_Target_Enc and, hospital_death is 0.03715913438353709.
# Correlation between the new feature, apache_3j_bodysystem_Kfold_Target_Enc and, hospital_death is 0.11734970574000511.
# Correlation between the new feature, apache_2_bodysystem_Kfold_Target_Enc and, hospital_death is 0.10090124743262772.
# Correlation between the new feature, age_factor_Kfold_Target_Enc and, hospital_death is 0.09811973880023082.
# Correlation between the new feature, resprate_min_Kfold_Target_Enc and, hospital_death is 0.060105365011684446.
# Correlation between the new feature, resprate_max_Kfold_Target_Enc and, hospital_death is -0.013425690356276861.
# Correlation between the new feature, temp_class_Kfold_Target_Enc and, hospital_death is 0.07878605269016843.
# Correlation between the new feature, weightclass_Kfold_Target_Enc and, hospital_death is 0.025927837444002143.
# Data shape: (82542, 212) (9171, 212)
# Training until validation scores don't improve for 400 rounds
# [250]	training's auc: 0.90819	valid_1's auc: 0.895362
# [500]	training's auc: 0.92374	valid_1's auc: 0.901995
# [750]	training's auc: 0.934228	valid_1's auc: 0.90552
# [1000]	training's auc: 0.942192	valid_1's auc: 0.907312
# [1250]	training's auc: 0.949232	valid_1's auc: 0.908487
# [1500]	training's auc: 0.955053	valid_1's auc: 0.909456
# [1750]	training's auc: 0.960339	valid_1's auc: 0.90992
# [2000]	training's auc: 0.965098	valid_1's auc: 0.910394
# [2250]	training's auc: 0.969222	valid_1's auc: 0.910759
# [2500]	training's auc: 0.973088	valid_1's auc: 0.911164
# [2750]	training's auc: 0.976278	valid_1's auc: 0.911354
# [3000]	training's auc: 0.979258	valid_1's auc: 0.911571
# [3250]	training's auc: 0.981888	valid_1's auc: 0.911652
# [3500]	training's auc: 0.984332	valid_1's auc: 0.91177
# [3750]	training's auc: 0.98638	valid_1's auc: 0.911816
# [4000]	training's auc: 0.988239	valid_1's auc: 0.911914
# [4250]	training's auc: 0.989798	valid_1's auc: 0.912005
# [4500]	training's auc: 0.991246	valid_1's auc: 0.911994
# [4750]	training's auc: 0.992472	valid_1's auc: 0.911995
# Early stopping, best iteration is:
# [4544]	training's auc: 0.991477	valid_1's auc: 0.91205
# --------------------------------
# FOLD 7: AUC = 0.912050
# --------------------------------
#
# Correlation between the new feature, hospital_id_Kfold_Target_Enc and, hospital_death is 0.032654416688476726.
# Correlation between the new feature, ethnicity_Kfold_Target_Enc and, hospital_death is -0.024182397911282936.
# Correlation between the new feature, gender_Kfold_Target_Enc and, hospital_death is -0.028745001751423145.
# Correlation between the new feature, hospital_admit_source_Kfold_Target_Enc and, hospital_death is 0.09350788828903332.
# Correlation between the new feature, icu_admit_source_Kfold_Target_Enc and, hospital_death is 0.10746447857119626.
# Correlation between the new feature, icu_id_Kfold_Target_Enc and, hospital_death is 0.04667353318448651.
# Correlation between the new feature, icu_stay_type_Kfold_Target_Enc and, hospital_death is 0.0023725142287465122.
# Correlation between the new feature, icu_type_Kfold_Target_Enc and, hospital_death is 0.03739255849680397.
# Correlation between the new feature, apache_3j_bodysystem_Kfold_Target_Enc and, hospital_death is 0.11690327339929993.
# Correlation between the new feature, apache_2_bodysystem_Kfold_Target_Enc and, hospital_death is 0.09936515302499374.
# Correlation between the new feature, age_factor_Kfold_Target_Enc and, hospital_death is 0.09811245220642738.
# Correlation between the new feature, resprate_min_Kfold_Target_Enc and, hospital_death is 0.06642838401365928.
# Correlation between the new feature, resprate_max_Kfold_Target_Enc and, hospital_death is -0.012407627947350827.
# Correlation between the new feature, temp_class_Kfold_Target_Enc and, hospital_death is 0.07516313853575987.
# Correlation between the new feature, weightclass_Kfold_Target_Enc and, hospital_death is 0.022188150335083204.
# Data shape: (82542, 212) (9171, 212)
# Training until validation scores don't improve for 400 rounds
# [250]	training's auc: 0.910128	valid_1's auc: 0.881337
# [500]	training's auc: 0.925534	valid_1's auc: 0.888141
# [750]	training's auc: 0.93597	valid_1's auc: 0.89162
# [1000]	training's auc: 0.944301	valid_1's auc: 0.893822
# [1250]	training's auc: 0.950769	valid_1's auc: 0.895074
# [1500]	training's auc: 0.956598	valid_1's auc: 0.895635
# [1750]	training's auc: 0.962196	valid_1's auc: 0.896054
# [2000]	training's auc: 0.966999	valid_1's auc: 0.896495
# [2250]	training's auc: 0.971107	valid_1's auc: 0.896894
# [2500]	training's auc: 0.974643	valid_1's auc: 0.897194
# [2750]	training's auc: 0.977795	valid_1's auc: 0.897373
# [3000]	training's auc: 0.980549	valid_1's auc: 0.897578
# [3250]	training's auc: 0.982953	valid_1's auc: 0.897825
# [3500]	training's auc: 0.985182	valid_1's auc: 0.897899
# [3750]	training's auc: 0.987257	valid_1's auc: 0.898006
# [4000]	training's auc: 0.988988	valid_1's auc: 0.898147
# [4250]	training's auc: 0.990547	valid_1's auc: 0.898131
# Early stopping, best iteration is:
# [4019]	training's auc: 0.989106	valid_1's auc: 0.898191
# --------------------------------
# FOLD 8: AUC = 0.898191
# --------------------------------
#
# Correlation between the new feature, hospital_id_Kfold_Target_Enc and, hospital_death is 0.03407176718669708.
# Correlation between the new feature, ethnicity_Kfold_Target_Enc and, hospital_death is -0.02086760755882093.
# Correlation between the new feature, gender_Kfold_Target_Enc and, hospital_death is -0.027258586263820318.
# Correlation between the new feature, hospital_admit_source_Kfold_Target_Enc and, hospital_death is 0.09363941117539594.
# Correlation between the new feature, icu_admit_source_Kfold_Target_Enc and, hospital_death is 0.10656231108714426.
# Correlation between the new feature, icu_id_Kfold_Target_Enc and, hospital_death is 0.04939363227842238.
# Correlation between the new feature, icu_stay_type_Kfold_Target_Enc and, hospital_death is 0.0027453398048656926.
# Correlation between the new feature, icu_type_Kfold_Target_Enc and, hospital_death is 0.037242449351348995.
# Correlation between the new feature, apache_3j_bodysystem_Kfold_Target_Enc and, hospital_death is 0.11688497594739447.
# Correlation between the new feature, apache_2_bodysystem_Kfold_Target_Enc and, hospital_death is 0.10115272231108602.
# Correlation between the new feature, age_factor_Kfold_Target_Enc and, hospital_death is 0.0991075261994092.
# Correlation between the new feature, resprate_min_Kfold_Target_Enc and, hospital_death is 0.06404187087762604.
# Correlation between the new feature, resprate_max_Kfold_Target_Enc and, hospital_death is -0.011946480807182242.
# Correlation between the new feature, temp_class_Kfold_Target_Enc and, hospital_death is 0.07825699620187071.
# Correlation between the new feature, weightclass_Kfold_Target_Enc and, hospital_death is 0.02444369682900834.
# Data shape: (82542, 212) (9171, 212)
# Training until validation scores don't improve for 400 rounds
# [250]	training's auc: 0.908452	valid_1's auc: 0.888613
# [500]	training's auc: 0.924314	valid_1's auc: 0.896501
# [750]	training's auc: 0.935323	valid_1's auc: 0.899861
# [1000]	training's auc: 0.943466	valid_1's auc: 0.901619
# [1250]	training's auc: 0.950543	valid_1's auc: 0.902434
# [1500]	training's auc: 0.956293	valid_1's auc: 0.902851
# [1750]	training's auc: 0.961351	valid_1's auc: 0.903117
# [2000]	training's auc: 0.965853	valid_1's auc: 0.903472
# [2250]	training's auc: 0.969758	valid_1's auc: 0.903776
# [2500]	training's auc: 0.973363	valid_1's auc: 0.904074
# [2750]	training's auc: 0.976556	valid_1's auc: 0.904299
# [3000]	training's auc: 0.97935	valid_1's auc: 0.90439
# [3250]	training's auc: 0.982053	valid_1's auc: 0.904388
# [3500]	training's auc: 0.984397	valid_1's auc: 0.904519
# [3750]	training's auc: 0.986491	valid_1's auc: 0.904675
# [4000]	training's auc: 0.988276	valid_1's auc: 0.904651
# Early stopping, best iteration is:
# [3843]	training's auc: 0.987188	valid_1's auc: 0.904733
# --------------------------------
# FOLD 9: AUC = 0.904733
# --------------------------------
#
# Correlation between the new feature, hospital_id_Kfold_Target_Enc and, hospital_death is 0.03354516756373431.
# Correlation between the new feature, ethnicity_Kfold_Target_Enc and, hospital_death is -0.017979422731229208.
# Correlation between the new feature, gender_Kfold_Target_Enc and, hospital_death is -0.025809546373047946.
# Correlation between the new feature, hospital_admit_source_Kfold_Target_Enc and, hospital_death is 0.09678467976063382.
# Correlation between the new feature, icu_admit_source_Kfold_Target_Enc and, hospital_death is 0.10861415735924024.
# Correlation between the new feature, icu_id_Kfold_Target_Enc and, hospital_death is 0.048449781213503185.
# Correlation between the new feature, icu_stay_type_Kfold_Target_Enc and, hospital_death is -0.000554152369644836.
# Correlation between the new feature, icu_type_Kfold_Target_Enc and, hospital_death is 0.03893494481599879.
# Correlation between the new feature, apache_3j_bodysystem_Kfold_Target_Enc and, hospital_death is 0.11625707102468977.
# Correlation between the new feature, apache_2_bodysystem_Kfold_Target_Enc and, hospital_death is 0.09993926379786959.
# Correlation between the new feature, age_factor_Kfold_Target_Enc and, hospital_death is 0.09961464299098721.
# Correlation between the new feature, resprate_min_Kfold_Target_Enc and, hospital_death is 0.06589515565851319.
# Correlation between the new feature, resprate_max_Kfold_Target_Enc and, hospital_death is -0.014280357640746026.
# Correlation between the new feature, temp_class_Kfold_Target_Enc and, hospital_death is 0.07550829095573568.
# Correlation between the new feature, weightclass_Kfold_Target_Enc and, hospital_death is 0.02756715615889512.
# Data shape: (82542, 212) (9171, 212)
# Training until validation scores don't improve for 400 rounds
# [250]	training's auc: 0.908828	valid_1's auc: 0.889084
# [500]	training's auc: 0.923738	valid_1's auc: 0.896847
# [750]	training's auc: 0.933993	valid_1's auc: 0.900243
# [1000]	training's auc: 0.942371	valid_1's auc: 0.901749
# [1250]	training's auc: 0.948579	valid_1's auc: 0.902524
# [1500]	training's auc: 0.954209	valid_1's auc: 0.903172
# [1750]	training's auc: 0.959321	valid_1's auc: 0.903783
# [2000]	training's auc: 0.963946	valid_1's auc: 0.904057
# [2250]	training's auc: 0.968314	valid_1's auc: 0.904497
# [2500]	training's auc: 0.972117	valid_1's auc: 0.904697
# [2750]	training's auc: 0.975527	valid_1's auc: 0.904758
# [3000]	training's auc: 0.978604	valid_1's auc: 0.904833
# [3250]	training's auc: 0.981322	valid_1's auc: 0.904968
# [3500]	training's auc: 0.983695	valid_1's auc: 0.904989
# Early stopping, best iteration is:
# [3321]	training's auc: 0.982013	valid_1's auc: 0.90503
# --------------------------------
# FOLD10: AUC = 0.905030
# --------------------------------
#
# --------------------------------
# - OOF AUC = 0.907495
# - CV TIME = 7.76 min
# --------------------------------

# %% [markdown]
# ### EVALUATION

# %%
############ RECHECK PERFORMANCE  


# check performance
print(np.round(roc_auc_score(y, preds_oof), 5))


############ TRACK RESULTS
# Out:
# 0.90749

# %%
############ VARIABLE IMPORTANCE

# load importance    
top_feats = 300
cols = importances[['Feature', 'Importance']].groupby('Feature').mean().sort_values(by = 'Importance', ascending = False)[0:top_feats].index
importance = importances.loc[importances.Feature.isin(cols)]
    
# plot variable importance
plt.figure(figsize = (10, 150))
sns.barplot(x = 'Importance', y = 'Feature', data = importance.sort_values(by = 'Importance', ascending = False))
plt.tight_layout()
plt.savefig('./var_importance.pdf')

# %% [markdown]
# SUBMISSION

# %%
# file name
model = 'lgb_v99_seed111'
perf  = str(round(cv_perf, 6))[2:7]
name  = model + '_' + perf
name
# Out:
# 'lgb_v99_seed111_90749'

# %%
# export OOF preds
oof = pd.DataFrame({'encounter_id': train['encounter_id'], 'hospital_death': preds_oof})
oof.to_csv('../oof_preds/' + str(name) + '.csv', index = False)
oof.head()
# Out:
#    encounter_id  hospital_death
# 0       66154.0        0.045259
# 1      114252.0        0.420452
# 2      119783.0        0.000867
# 3       79267.0        0.024274
# 4       92056.0        0.006752

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(preds_test.reshape(-1,1))
preds_test = scaler.transform(preds_test.reshape(-1,1)).reshape(-1)

# %%
# export submission
sub = pd.DataFrame({'encounter_id': test['encounter_id'], 'hospital_death': preds_test})
sub.to_csv('../submissions/' + str(name) + '.csv', index = False)
sub.head()
# Out:
#    encounter_id  hospital_death
# 0             2        0.007726
# 1             5        0.019570
# 2             7        0.006696
# 3             8        0.071526
# 4            10        0.573404
